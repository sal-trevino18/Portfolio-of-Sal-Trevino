# %% [markdown]
# # Going Live with CCXT

# %% [markdown]
# ### Import Libraries and Dependencies

# %%
# Import libraries and dependencies
import ccxt
import os
import pandas as pd
from decouple import config

kraken_public_key = config('KRAKEN_PUBLIC_KEY')
kraken_secret_key = config('KRAKEN_SECRET_KEY')

# %% [markdown]
# ### Set Public and Private Keys for Kraken Exchange via the CCXT library

# %%
# Set the public and private keys for the API
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
})

# %% [markdown]
# ### Connect to Kraken and Load Available Cyptocurrency Data

# %%
# Connect to Kraken and load the available cryptocurrencies
crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame(crypto_details)

# Display sample data
crypto_df
# Out:
#                                                     1INCH/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 1.0, 'max': None}, 'price':...
# id                                                   1INCHEUR
# symbol                                              1INCH/EUR
# base                                                    1INCH
# quote                                                     EUR
# baseId                                                  1INCH
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': '1INCHEUR', 'wsname': '1INCH/EUR',...
# altname                                              1INCHEUR
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                     1INCH/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 1.0, 'max': None}, 'price':...
# id                                                   1INCHUSD
# symbol                                              1INCH/USD
# base                                                    1INCH
# quote                                                     USD
# baseId                                                  1INCH
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': '1INCHUSD', 'wsname': '1INCH/USD',...
# altname                                              1INCHUSD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                      AAVE/AUD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': None}, 'price'...
# id                                                    AAVEAUD
# symbol                                               AAVE/AUD
# base                                                     AAVE
# quote                                                     AUD
# baseId                                                   AAVE
# quoteId                                                  ZAUD
# darkpool                                                False
# info        {'altname': 'AAVEAUD', 'wsname': 'AAVE/AUD', '...
# altname                                               AAVEAUD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                      AAVE/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 0.02, 'max': None}, 'price'...
# id                                                    AAVEETH
# symbol                                               AAVE/ETH
# base                                                     AAVE
# quote                                                     ETH
# baseId                                                   AAVE
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'AAVEETH', 'wsname': 'AAVE/ETH', '...
# altname                                               AAVEETH
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                      AAVE/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': None}, 'price'...
# id                                                    AAVEEUR
# symbol                                               AAVE/EUR
# base                                                     AAVE
# quote                                                     EUR
# baseId                                                   AAVE
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'AAVEEUR', 'wsname': 'AAVE/EUR', '...
# altname                                               AAVEEUR
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                      AAVE/GBP  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': None}, 'price'...
# id                                                    AAVEGBP
# symbol                                               AAVE/GBP
# base                                                     AAVE
# quote                                                     GBP
# baseId                                                   AAVE
# quoteId                                                  ZGBP
# darkpool                                                False
# info        {'altname': 'AAVEGBP', 'wsname': 'AAVE/GBP', '...
# altname                                               AAVEGBP
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                      AAVE/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': None}, 'price'...
# id                                                    AAVEUSD
# symbol                                               AAVE/USD
# base                                                     AAVE
# quote                                                     USD
# baseId                                                   AAVE
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'AAVEUSD', 'wsname': 'AAVE/USD', '...
# altname                                               AAVEUSD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                      AAVE/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 0.02, 'max': None}, 'price'...
# id                                                    AAVEXBT
# symbol                                               AAVE/BTC
# base                                                     AAVE
# quote                                                     BTC
# baseId                                                   AAVE
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'AAVEXBT', 'wsname': 'AAVE/XBT', '...
# altname                                               AAVEXBT
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       ADA/AUD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 2.5, 'max': None}, 'price':...
# id                                                     ADAAUD
# symbol                                                ADA/AUD
# base                                                      ADA
# quote                                                     AUD
# baseId                                                    ADA
# quoteId                                                  ZAUD
# darkpool                                                False
# info        {'altname': 'ADAAUD', 'wsname': 'ADA/AUD', 'ac...
# altname                                                ADAAUD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       ADA/ETH  ...  \
# percentage                                               True  ...
# tierBased                                                True  ...
# taker                                                  0.0026  ...
# maker                                                  0.0016  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
# precision                           {'amount': 8, 'price': 7}  ...
# limits      {'amount': {'min': 2.5, 'max': None}, 'price':...  ...
# id                                                     ADAETH  ...
# symbol                                                ADA/ETH  ...
# base                                                      ADA  ...
# quote                                                     ETH  ...
# baseId                                                    ADA  ...
# quoteId                                                  XETH  ...
# darkpool                                                False  ...
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...  ...
# altname                                                ADAETH  ...
# type                                                     spot  ...
# spot                                                     True  ...
# active                                                   True  ...
#
#                                                       YFI/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 0}
# limits      {'amount': {'min': 0.00015, 'max': None}, 'pri...
# id                                                     YFIUSD
# symbol                                                YFI/USD
# base                                                      YFI
# quote                                                     USD
# baseId                                                    YFI
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'YFIUSD', 'wsname': 'YFI/USD', 'ac...
# altname                                                YFIUSD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       YFI/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 0.00015, 'max': None}, 'pri...
# id                                                     YFIXBT
# symbol                                                YFI/BTC
# base                                                      YFI
# quote                                                     BTC
# baseId                                                    YFI
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'YFIXBT', 'wsname': 'YFI/XBT', 'ac...
# altname                                                YFIXBT
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       EUR/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 5.0, 'max': None}, 'price':...
# id                                                   ZEURZUSD
# symbol                                                EUR/USD
# base                                                      EUR
# quote                                                     USD
# baseId                                                   ZEUR
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'EURUSD', 'wsname': 'EUR/USD', 'ac...
# altname                                                EURUSD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       GBP/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 5.0, 'max': None}, 'price':...
# id                                                   ZGBPZUSD
# symbol                                                GBP/USD
# base                                                      GBP
# quote                                                     USD
# baseId                                                   ZGBP
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'GBPUSD', 'wsname': 'GBP/USD', 'ac...
# altname                                                GBPUSD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       ZRX/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': None}, 'price':...
# id                                                     ZRXEUR
# symbol                                                ZRX/EUR
# base                                                      ZRX
# quote                                                     EUR
# baseId                                                    ZRX
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ZRXEUR', 'wsname': 'ZRX/EUR', 'ac...
# altname                                                ZRXEUR
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       ZRX/GBP  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': None}, 'price':...
# id                                                     ZRXGBP
# symbol                                                ZRX/GBP
# base                                                      ZRX
# quote                                                     GBP
# baseId                                                    ZRX
# quoteId                                                  ZGBP
# darkpool                                                False
# info        {'altname': 'ZRXGBP', 'wsname': 'ZRX/GBP', 'ac...
# altname                                                ZRXGBP
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       ZRX/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': None}, 'price':...
# id                                                     ZRXUSD
# symbol                                                ZRX/USD
# base                                                      ZRX
# quote                                                     USD
# baseId                                                    ZRX
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ZRXUSD', 'wsname': 'ZRX/USD', 'ac...
# altname                                                ZRXUSD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       ZRX/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 8}
# limits      {'amount': {'min': 5.0, 'max': None}, 'price':...
# id                                                     ZRXXBT
# symbol                                                ZRX/BTC
# base                                                      ZRX
# quote                                                     BTC
# baseId                                                    ZRX
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'ZRXXBT', 'wsname': 'ZRX/XBT', 'ac...
# altname                                                ZRXXBT
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       USD/CAD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 10.0, 'max': None}, 'price'...
# id                                                   ZUSDZCAD
# symbol                                                USD/CAD
# base                                                      USD
# quote                                                     CAD
# baseId                                                   ZUSD
# quoteId                                                  ZCAD
# darkpool                                                False
# info        {'altname': 'USDCAD', 'wsname': 'USD/CAD', 'ac...
# altname                                                USDCAD
# type                                                     spot
# spot                                                     True
# active                                                   True
#
#                                                       USD/JPY
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 10.0, 'max': None}, 'price'...
# id                                                   ZUSDZJPY
# symbol                                                USD/JPY
# base                                                      USD
# quote                                                     JPY
# baseId                                                   ZUSD
# quoteId                                                  ZJPY
# darkpool                                                False
# info        {'altname': 'USDJPY', 'wsname': 'USD/JPY', 'ac...
# altname                                                USDJPY
# type                                                     spot
# spot                                                     True
# active                                                   True
#
# [19 rows x 406 columns]

# %% [markdown]
# ### List Available Cryptocurrencies for Trading

# %%
# Print column values of DataFrame
print(type(crypto_df.columns.values))
print(crypto_df.columns.values)
print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['1INCH/EUR' '1INCH/USD' 'AAVE/AUD' 'AAVE/ETH' 'AAVE/EUR' 'AAVE/GBP'
#  'AAVE/USD' 'AAVE/BTC' 'ADA/AUD' 'ADA/ETH' 'ADA/EUR' 'ADA/GBP' 'ADA/USD'
#  'ADA/USDT' 'ADA/BTC' 'ALGO/ETH' 'ALGO/EUR' 'ALGO/GBP' 'ALGO/USD'
#  'ALGO/BTC' 'ANKR/EUR' 'ANKR/GBP' 'ANKR/USD' 'ANKR/BTC' 'ANT/ETH'
#  'ANT/EUR' 'ANT/USD' 'ANT/BTC' 'ATOM/AUD' 'ATOM/ETH' 'ATOM/EUR' 'ATOM/GBP'
#  'ATOM/USD' 'ATOM/BTC' 'AUD/JPY' 'AUD/USD' 'AVAX/EUR' 'AVAX/USD' 'AXS/EUR'
#  'AXS/USD' 'BADGER/EUR' 'BADGER/USD' 'BAL/ETH' 'BAL/EUR' 'BAL/USD'
#  'BAL/BTC' 'BAND/EUR' 'BAND/USD' 'BAT/ETH' 'BAT/EUR' 'BAT/USD' 'BAT/BTC'
#  'BCH/AUD' 'BCH/ETH' 'BCH/EUR' 'BCH/GBP' 'BCH/JPY' 'BCH/USD' 'BCH/USDT'
#  'BCH/BTC' 'BNC/EUR' 'BNC/USD' 'BNT/EUR' 'BNT/GBP' 'BNT/USD' 'BNT/BTC'
#  'CHZ/EUR' 'CHZ/USD' 'COMP/ETH' 'COMP/EUR' 'COMP/USD' 'COMP/BTC' 'CQT/EUR'
#  'CQT/USD' 'CRV/ETH' 'CRV/EUR' 'CRV/USD' 'CRV/BTC' 'CTSI/EUR' 'CTSI/USD'
#  'DAI/EUR' 'DAI/USD' 'DAI/USDT' 'DASH/EUR' 'DASH/USD' 'DASH/BTC' 'DOT/AUD'
#  'DOT/ETH' 'DOT/EUR' 'DOT/GBP' 'DOT/USD' 'DOT/USDT' 'DOT/BTC' 'DYDX/EUR'
#  'DYDX/USD' 'ENJ/EUR' 'ENJ/GBP' 'ENJ/USD' 'ENJ/BTC' 'EOS/ETH' 'EOS/EUR'
#  'EOS/USD' 'EOS/USDT' 'EOS/BTC' 'ETH2.S/ETH' 'ETH/AUD' 'ETH/CHF' 'ETH/DAI'
#  'ETH/USDC' 'ETH/USDT' 'EUR/AUD' 'EUR/CAD' 'EUR/CHF' 'EUR/GBP' 'EUR/JPY'
#  'EWT/EUR' 'EWT/GBP' 'EWT/USD' 'EWT/BTC' 'FIL/AUD' 'FIL/ETH' 'FIL/EUR'
#  'FIL/GBP' 'FIL/USD' 'FIL/BTC' 'FLOW/ETH' 'FLOW/EUR' 'FLOW/GBP' 'FLOW/USD'
#  'FLOW/BTC' 'GHST/EUR' 'GHST/GBP' 'GHST/USD' 'GHST/BTC' 'GNO/ETH'
#  'GNO/EUR' 'GNO/USD' 'GNO/BTC' 'GRT/AUD' 'GRT/ETH' 'GRT/EUR' 'GRT/GBP'
#  'GRT/USD' 'GRT/BTC' 'ICX/ETH' 'ICX/EUR' 'ICX/USD' 'ICX/BTC' 'INJ/EUR'
#  'INJ/USD' 'KAR/EUR' 'KAR/USD' 'KAVA/ETH' 'KAVA/EUR' 'KAVA/USD' 'KAVA/BTC'
#  'KEEP/ETH' 'KEEP/EUR' 'KEEP/USD' 'KEEP/BTC' 'KILT/EUR' 'KILT/USD'
#  'KINT/EUR' 'KINT/USD' 'KNC/ETH' 'KNC/EUR' 'KNC/USD' 'KNC/BTC' 'KSM/AUD'
#  'KSM/DOT' 'KSM/ETH' 'KSM/EUR' 'KSM/GBP' 'KSM/USD' 'KSM/BTC' 'LINK/AUD'
#  'LINK/ETH' 'LINK/EUR' 'LINK/GBP' 'LINK/USD' 'LINK/USDT' 'LINK/BTC'
#  'LPT/EUR' 'LPT/GBP' 'LPT/USD' 'LPT/BTC' 'LRC/EUR' 'LRC/USD' 'LSK/ETH'
#  'LSK/EUR' 'LSK/USD' 'LSK/BTC' 'LTC/AUD' 'LTC/ETH' 'LTC/GBP' 'LTC/USDT'
#  'LUNA/EUR' 'LUNA/USD' 'MANA/ETH' 'MANA/EUR' 'MANA/USD' 'MANA/BTC'
#  'MATIC/EUR' 'MATIC/GBP' 'MATIC/USD' 'MATIC/BTC' 'MINA/EUR' 'MINA/GBP'
#  'MINA/USD' 'MINA/BTC' 'MIR/EUR' 'MIR/USD' 'MKR/EUR' 'MKR/GBP' 'MKR/USD'
#  'MKR/BTC' 'MOVR/EUR' 'MOVR/USD' 'NANO/ETH' 'NANO/EUR' 'NANO/USD'
#  'NANO/BTC' 'OCEAN/EUR' 'OCEAN/GBP' 'OCEAN/USD' 'OCEAN/BTC' 'OGN/EUR'
#  'OGN/USD' 'OMG/ETH' 'OMG/EUR' 'OMG/USD' 'OMG/BTC' 'OXT/ETH' 'OXT/EUR'
#  'OXT/USD' 'OXT/BTC' 'OXY/EUR' 'OXY/USD' 'PAXG/ETH' 'PAXG/EUR' 'PAXG/USD'
#  'PAXG/BTC' 'PERP/EUR' 'PERP/USD' 'PHA/EUR' 'PHA/USD' 'QTUM/ETH'
#  'QTUM/EUR' 'QTUM/USD' 'QTUM/BTC' 'RARI/EUR' 'RARI/GBP' 'RARI/USD'
#  'RARI/BTC' 'RAY/EUR' 'RAY/USD' 'REN/EUR' 'REN/GBP' 'REN/USD' 'REN/BTC'
#  'REP/ETH' 'REP/EUR' 'REP/USD' 'REP/BTC' 'SAND/EUR' 'SAND/GBP' 'SAND/USD'
#  'SAND/BTC' 'SC/ETH' 'SC/EUR' 'SC/USD' 'SC/BTC' 'SDN/EUR' 'SDN/USD'
#  'SHIB/EUR' 'SHIB/USD' 'SNX/AUD' 'SNX/ETH' 'SNX/EUR' 'SNX/GBP' 'SNX/USD'
#  'SNX/BTC' 'SOL/EUR' 'SOL/GBP' 'SOL/USD' 'SOL/BTC' 'SRM/EUR' 'SRM/GBP'
#  'SRM/USD' 'SRM/BTC' 'STORJ/ETH' 'STORJ/EUR' 'STORJ/USD' 'STORJ/BTC'
#  'SUSHI/EUR' 'SUSHI/GBP' 'SUSHI/USD' 'SUSHI/BTC' 'TBTC/ETH' 'TBTC/EUR'
#  'TBTC/USD' 'TBTC/BTC' 'TRX/ETH' 'TRX/EUR' 'TRX/USD' 'TRX/BTC' 'UNI/ETH'
#  'UNI/EUR' 'UNI/USD' 'UNI/BTC' 'USDC/AUD' 'USDC/EUR' 'USDC/GBP' 'USD/CHF'
#  'USDC/USD' 'USDC/USDT' 'USDT/AUD' 'USDT/CAD' 'USDT/CHF' 'USDT/EUR'
#  'USDT/GBP' 'USDT/JPY' 'USDT/USD' 'WAVES/ETH' 'WAVES/EUR' 'WAVES/USD'
#  'WAVES/BTC' 'WBTC/EUR' 'WBTC/USD' 'WBTC/BTC' 'BTC/AUD' 'BTC/CHF'
#  'BTC/DAI' 'BTC/USDC' 'BTC/USDT' 'DOGE/EUR' 'DOGE/USD' 'DOGE/USDT'
#  'ETC/ETH' 'ETC/BTC' 'ETC/EUR' 'ETC/USD' 'ETH/BTC' 'ETH/CAD' 'ETH/EUR'
#  'ETH/GBP' 'ETH/JPY' 'ETH/USD' 'LTC/BTC' 'LTC/EUR' 'LTC/JPY' 'LTC/USD'
#  'MLN/ETH' 'MLN/BTC' 'MLN/EUR' 'MLN/USD' 'REPV1/ETH' 'REPV1/BTC'
#  'REPV1/EUR' 'REPV1/USD' 'XRP/AUD' 'XRP/ETH' 'XRP/GBP' 'XRP/USDT'
#  'XTZ/AUD' 'XTZ/ETH' 'XTZ/EUR' 'XTZ/GBP' 'XTZ/USD' 'XTZ/BTC' 'BTC/CAD'
#  'BTC/EUR' 'BTC/GBP' 'BTC/JPY' 'BTC/USD' 'DOGE/BTC' 'XLM/BTC' 'XLM/AUD'
#  'XLM/EUR' 'XLM/GBP' 'XLM/USD' 'XMR/BTC' 'XMR/EUR' 'XMR/USD' 'XRP/BTC'
#  'XRP/CAD' 'XRP/EUR' 'XRP/JPY' 'XRP/USD' 'ZEC/BTC' 'ZEC/EUR' 'ZEC/USD'
#  'YFI/AUD' 'YFI/ETH' 'YFI/EUR' 'YFI/GBP' 'YFI/USD' 'YFI/BTC' 'EUR/USD'
#  'GBP/USD' 'ZRX/EUR' 'ZRX/GBP' 'ZRX/USD' 'ZRX/BTC' 'USD/CAD' 'USD/JPY']
# 406

# %%
# Show list of available functions for the current exchange (in this case Kraken)
exchange.has
# Out:
# {'publicAPI': True,
#  'privateAPI': True,
#  'margin': True,
#  'swap': None,
#  'future': None,
#  'addMargin': None,
#  'cancelAllOrders': True,
#  'cancelOrder': True,
#  'cancelOrders': None,
#  'CORS': None,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': None,
#  'editOrder': 'emulated',
#  'fetchAccounts': None,
#  'fetchBalance': True,
#  'fetchBidsAsks': None,
#  'fetchBorrowRate': False,
#  'fetchBorrowRateHistory': False,
#  'fetchBorrowRatesPerSymbol': None,
#  'fetchBorrowRates': False,
#  'fetchCanceledOrders': None,
#  'fetchClosedOrder': None,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDeposit': None,
#  'fetchDepositAddress': True,
#  'fetchDepositAddresses': None,
#  'fetchDepositAddressesByNetwork': None,
#  'fetchDeposits': True,
#  'fetchFundingFee': None,
#  'fetchFundingFees': None,
#  'fetchFundingHistory': None,
#  'fetchFundingRate': None,
#  'fetchFundingRateHistory': None,
#  'fetchFundingRates': None,
#  'fetchIndexOHLCV': None,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchLedgerEntry': True,
#  'fetchMarkets': True,
#  'fetchMarkOHLCV': None,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrder': None,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': None,
#  'fetchOrders': None,
#  'fetchOrderTrades': 'emulated',
#  'fetchPosition': None,
#  'fetchPositions': True,
#  'fetchPositionsRisk': None,
#  'fetchPremiumIndexOHLCV': False,
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': None,
#  'fetchTradingFees': True,
#  'fetchTradingLimits': None,
#  'fetchTransactions': None,
#  'fetchTransfers': None,
#  'fetchWithdrawAddress': None,
#  'fetchWithdrawAddressesByNetwork': None,
#  'fetchWithdrawal': None,
#  'fetchWithdrawals': True,
#  'loadLeverageBrackets': None,
#  'loadMarkets': True,
#  'reduceMargin': None,
#  'setLeverage': None,
#  'setMarginMode': False,
#  'setPositionMode': None,
#  'signIn': None,
#  'transfer': None,
#  'withdraw': True}

# %% [markdown]
# ### Fetch Historical Data for BTC/USD

# %%
# Fetch daily candlestick bar data from `BTC/USD`
historical_prices = exchange.fetch_ohlcv("BTC/USD", "1d")

# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp     open     high      low    close       volume
# 0    1579392000000   8905.3   9185.0   8470.0   8705.8  8532.302677
# 1    1579478400000   8705.8   8731.9   8510.0   8629.4  3779.492362
# 2    1579564800000   8628.7   8782.2   8333.0   8723.3  4521.519072
# 3    1579651200000   8723.3   8795.0   8565.4   8659.0  3097.912569
# 4    1579737600000   8658.9   8662.1   8281.0   8390.1  5865.700032
# ..             ...      ...      ...      ...      ...          ...
# 715  1641168000000  47301.2  47567.2  45707.9  46452.6  2133.141779
# 716  1641254400000  46452.5  47500.0  45548.7  45858.5  2219.890257
# 717  1641340800000  45858.5  47066.5  42505.0  43410.0  4070.482878
# 718  1641427200000  43432.5  43748.0  42424.0  43124.4  4794.701325
# 719  1641513600000  43124.5  43134.9  41005.0  41423.7  2065.914041
#
# [720 rows x 6 columns]

# %% [markdown]
# ### Convert Epoch Timestamp to Readable Date Format

# %%
# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["timestamp"], unit="ms"
)
historical_prices_df.head()
# Out:
#        timestamp    open    high     low   close       volume       date
# 0  1579392000000  8905.3  9185.0  8470.0  8705.8  8532.302677 2020-01-19
# 1  1579478400000  8705.8  8731.9  8510.0  8629.4  3779.492362 2020-01-20
# 2  1579564800000  8628.7  8782.2  8333.0  8723.3  4521.519072 2020-01-21
# 3  1579651200000  8723.3  8795.0  8565.4  8659.0  3097.912569 2020-01-22
# 4  1579737600000  8658.9  8662.1  8281.0  8390.1  5865.700032 2020-01-23

# %% [markdown]
# ### Fetch Latest Data for BTC/USD

# %%
# Fetch current price details for `BTC/USD`
current_price = exchange.fetch_ticker('BTC/USD')

# Delete `info` key-value pair
del current_price['info']

current_price
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1641541480583,
#  'datetime': '2022-01-07T07:44:40.583Z',
#  'high': 43666.9,
#  'low': 41005.0,
#  'bid': 41442.7,
#  'bidVolume': None,
#  'ask': 41446.5,
#  'askVolume': None,
#  'vwap': 42642.30246,
#  'open': 43124.5,
#  'close': 41441.6,
#  'last': 41441.6,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 5275.89757848,
#  'quoteVolume': 224976420.28952575}

# %%
# Import data as a Pandas DataFrame
current_price_df = pd.DataFrame(current_price, index=[0])
current_price_df
# Out:
#     symbol      timestamp                  datetime     high      low  \
# 0  BTC/USD  1641541480583  2022-01-07T07:44:40.583Z  43666.9  41005.0
#
#        bid bidVolume      ask askVolume         vwap     open    close  \
# 0  41442.7      None  41446.5      None  42642.30246  43124.5  41441.6
#
#       last previousClose change percentage average   baseVolume   quoteVolume
# 0  41441.6          None   None       None    None  5275.897578  2.249764e+08

# %%
# Fetch balance
exchange.fetch_balance()
# Out:
# {'info': {'error': []},
#  'timestamp': None,
#  'datetime': None,
#  'free': {},
#  'used': {},
#  'total': {}}

# %%
# Fetch status
exchange.fetch_status()
# Out:
# {'status': 'ok', 'updated': 1641541487000, 'eta': None, 'url': None}

# %%
# Fetch open orders
exchange.fetch_open_orders()
# Out:
# []
