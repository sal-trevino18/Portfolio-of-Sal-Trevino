# %%
# Initializing imports.
from pathlib import Path
import os
import zipfile
import requests,io
import pandas as pd
import datetime as dt

# %%
# Assigned local path and read in Weather csv file.
file_path = Path("OHAREWEATHERDATA_2019.csv")
chi_weather = pd.read_csv('OHAREWEATHERDATA_2019.csv', infer_datetime_format = True)
chi_weather
# Out:
#          STATION                                        NAME        DATE  \
# 0    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/1/2019
# 1    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/2/2019
# 2    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/3/2019
# 3    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/4/2019
# 4    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/5/2019
# 5    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/6/2019
# 6    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/7/2019
# 7    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/8/2019
# 8    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    1/9/2019
# 9    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/10/2019
# 10   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/11/2019
# 11   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/12/2019
# 12   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/13/2019
# 13   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/14/2019
# 14   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/15/2019
# 15   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/16/2019
# 16   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/17/2019
# 17   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/18/2019
# 18   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/19/2019
# 19   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/20/2019
# 20   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/21/2019
# 21   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/22/2019
# 22   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/23/2019
# 23   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/24/2019
# 24   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/25/2019
# 25   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/26/2019
# 26   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/27/2019
# 27   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/28/2019
# 28   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/29/2019
# 29   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   1/30/2019
# ..           ...                                         ...         ...
# 335  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   12/2/2019
# 336  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   12/3/2019
# 337  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   12/4/2019
# 338  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   12/5/2019
# 339  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   12/6/2019
# 340  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   12/7/2019
# 341  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   12/8/2019
# 342  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US   12/9/2019
# 343  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/10/2019
# 344  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/11/2019
# 345  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/12/2019
# 346  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/13/2019
# 347  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/14/2019
# 348  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/15/2019
# 349  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/16/2019
# 350  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/17/2019
# 351  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/18/2019
# 352  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/19/2019
# 353  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/20/2019
# 354  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/21/2019
# 355  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/22/2019
# 356  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/23/2019
# 357  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/24/2019
# 358  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/25/2019
# 359  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/26/2019
# 360  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/27/2019
# 361  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/28/2019
# 362  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/29/2019
# 363  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/30/2019
# 364  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  12/31/2019
#
#       AWND  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN  ...  WSF2  WSF5  WT01  WT02  \
# 0     7.61  0.01   0.1   0.0    31    34    26  ...  16.1  21.0   1.0   NaN
# 1     8.72  0.01   0.1   0.0    28    30    26  ...  19.9  29.1   1.0   NaN
# 2    11.63  0.00   0.0   0.0    29    38    24  ...  17.0  27.1   NaN   NaN
# 3     8.05  0.00   0.0   0.0    37    48    31  ...  14.1  19.9   NaN   NaN
# 4     8.28  0.00   0.0   0.0    39    52    32  ...  18.1  23.9   NaN   NaN
# 5    11.63  0.00   0.0   0.0    38    40    30  ...  21.9  29.1   NaN   NaN
# 6    15.66  0.44   0.0   0.0    44    53    40  ...  25.1  36.9   1.0   NaN
# 7    14.54  0.00   0.0   0.0    41    45    24  ...  32.0  49.0   1.0   NaN
# 8    13.65  0.00   0.0   0.0    23    24    15  ...  23.0  33.1   NaN   NaN
# 9     4.47  0.00   0.0   0.0    18    24    14  ...  14.1  19.0   NaN   NaN
# 10    4.92  0.00   0.0   0.0    23    30    17  ...  13.0  19.0   NaN   NaN
# 11   11.41  0.12   2.2   0.0    30    32    29  ...  21.0  30.0   1.0   NaN
# 12   12.53  0.01   0.3   2.0    30    31    25  ...  19.9  25.9   1.0   NaN
# 13    8.28  0.00   0.0   2.0    25    27    23  ...  14.1  19.9   1.0   NaN
# 14   11.18  0.00   0.0   1.2    26    32    24  ...  21.0  31.1   1.0   NaN
# 15    9.40  0.00   0.0   1.2    31    34    28  ...  16.1  21.0   NaN   NaN
# 16    5.59  0.00   0.0   0.0    30    35    28  ...  12.1  14.1   1.0   NaN
# 17   10.51  0.12   1.3   0.0    30    31    27  ...  19.9  25.9   1.0   NaN
# 18   20.13  0.18   3.7   3.9    26    28    11  ...  31.1  38.9   1.0   NaN
# 19   13.42  0.00   0.0   5.1    12    14     4  ...  21.0  28.0   NaN   NaN
# 20    8.50  0.00   0.1   5.1     9    17     3  ...  17.0  23.0   1.0   NaN
# 21    9.40  0.18   0.5   5.1    19    33    13  ...  19.9  29.1   1.0   NaN
# 22    9.84  0.22   1.0   3.9    29    34    19  ...  17.0  23.9   1.0   1.0
# 23   11.63  0.00   0.4   5.1    17    22     2  ...  23.9  35.1   1.0   NaN
# 24    9.40  0.03   0.7   5.1     1     5    -6  ...  18.1  27.1   1.0   NaN
# 25    5.82  0.06   1.7   7.1     2    12    -7  ...  14.1  19.0   1.0   NaN
# 26    6.93  0.00   0.0   7.1     4    11    -5  ...  15.0  19.0   NaN   NaN
# 27   12.75  0.53   5.0   9.1    18    34     8  ...  25.9  35.1   1.0   NaN
# 28   14.54  0.00   0.3   9.8     6    10   -10  ...  29.1  44.1   1.0   NaN
# 29   15.21  0.00   0.0   7.9   -15   -10   -23  ...  23.9  36.9   NaN   NaN
# ..     ...   ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...
# 335  10.29  0.00   0.0   0.0    32    35    29  ...  21.0  29.1   NaN   NaN
# 336  11.86  0.00   0.0   0.0    32    40    29  ...  18.1  25.9   NaN   NaN
# 337  12.08  0.00   0.0   0.0    37    43    31  ...  25.1  38.0   NaN   NaN
# 338   6.71  0.00   0.0   0.0    36    45    27  ...  13.0  18.1   NaN   NaN
# 339   9.84  0.00   0.0   0.0    38    42    27  ...  25.9  35.1   NaN   NaN
# 340   8.28  0.00   0.0   0.0    31    37    25  ...  16.1  21.9   NaN   NaN
# 341  10.29  0.00   0.0   0.0    38    47    34  ...  19.9  28.0   1.0   NaN
# 342  12.97  0.05   0.0   0.0    46    47    24  ...  28.0  44.1   1.0   NaN
# 343  11.86  0.00   0.0   0.0    22    24    14  ...  21.9  31.1   NaN   NaN
# 344   7.38  0.00   0.1   0.0    18    24    13  ...  19.9  29.1   1.0   NaN
# 345  12.30  0.00   0.0   0.0    28    45    19  ...  23.9  35.1   NaN   NaN
# 346   4.92  0.00   0.0   0.0    40    45    34  ...  13.0  19.0   NaN   NaN
# 347   9.40  0.00   0.0   0.0    33    35    24  ...  19.9  29.1   1.0   NaN
# 348   6.04  0.00   0.0   0.0    24    26    19  ...  16.1  21.0   1.0   NaN
# 349   6.71  0.01   0.3   0.0    26    30    24  ...  14.1  17.0   1.0   NaN
# 350  10.74  0.00   0.0   0.0    25    29    19  ...  21.0  28.0   NaN   NaN
# 351   8.72  0.00   0.0   0.0    20    27    10  ...  17.0  25.1   NaN   NaN
# 352   8.50  0.00   0.0   0.0    23    35    15  ...  19.9  28.0   1.0   NaN
# 353   5.59  0.00   0.0   0.0    30    41    23  ...  13.0  17.0   1.0   NaN
# 354   7.61  0.00   0.0   0.0    38    47    32  ...  15.0  19.9   NaN   NaN
# 355  10.07  0.00   0.0   0.0    40    52    33  ...  16.1  23.0   NaN   NaN
# 356   7.61  0.00   0.0   0.0    42    52    33  ...  15.0  21.9   1.0   NaN
# 357   8.05  0.00   0.0   0.0    40    55    30  ...  17.0  23.9   1.0   1.0
# 358   8.72  0.00   0.0   0.0    47    57    37  ...  17.0  25.9   NaN   NaN
# 359  11.18  0.00   0.0   0.0    56    61    37  ...  18.1  30.0   NaN   NaN
# 360   7.16  0.00   0.0   0.0    37    37    28  ...  17.0  23.9   1.0   NaN
# 361   6.93  0.28   0.0   0.0    34    48    27  ...  14.1  17.0   1.0   NaN
# 362  10.96  0.93   0.0   0.0    52    57    47  ...  21.9  31.1   1.0   NaN
# 363  17.67  0.09   0.7   0.0    38    47    27  ...  30.0  45.0   1.0   NaN
# 364  14.54  0.08   0.8   2.0    26    28    24  ...  30.0  42.9   1.0   NaN
#
#      WT03  WT04  WT05  WT06  WT08  WT09
# 0     NaN   NaN   1.0   NaN   NaN   NaN
# 1     NaN   NaN   NaN   1.0   NaN   NaN
# 2     NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN
# 5     NaN   NaN   NaN   NaN   NaN   NaN
# 6     NaN   NaN   NaN   NaN   NaN   NaN
# 7     NaN   NaN   NaN   NaN   NaN   NaN
# 8     NaN   NaN   NaN   NaN   NaN   NaN
# 9     NaN   NaN   NaN   NaN   NaN   NaN
# 10    NaN   NaN   NaN   NaN   NaN   NaN
# 11    NaN   NaN   NaN   NaN   1.0   NaN
# 12    NaN   NaN   NaN   NaN   NaN   NaN
# 13    NaN   NaN   NaN   1.0   1.0   NaN
# 14    NaN   NaN   NaN   1.0   NaN   NaN
# 15    NaN   NaN   NaN   1.0   NaN   NaN
# 16    NaN   NaN   NaN   NaN   1.0   NaN
# 17    NaN   NaN   NaN   NaN   NaN   NaN
# 18    NaN   NaN   NaN   NaN   NaN   1.0
# 19    NaN   NaN   NaN   NaN   NaN   NaN
# 20    NaN   NaN   NaN   NaN   1.0   NaN
# 21    NaN   1.0   NaN   1.0   NaN   NaN
# 22    NaN   NaN   NaN   1.0   NaN   NaN
# 23    NaN   NaN   NaN   NaN   1.0   NaN
# 24    NaN   NaN   NaN   NaN   NaN   NaN
# 25    NaN   NaN   NaN   NaN   NaN   NaN
# 26    NaN   NaN   NaN   NaN   NaN   NaN
# 27    NaN   NaN   NaN   1.0   1.0   1.0
# 28    NaN   NaN   NaN   NaN   1.0   1.0
# 29    NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...   ...   ...   ...
# 335   NaN   NaN   NaN   NaN   NaN   NaN
# 336   NaN   NaN   NaN   NaN   NaN   NaN
# 337   NaN   NaN   NaN   NaN   NaN   NaN
# 338   NaN   NaN   NaN   NaN   NaN   NaN
# 339   NaN   NaN   NaN   NaN   NaN   NaN
# 340   NaN   NaN   NaN   NaN   NaN   NaN
# 341   NaN   NaN   NaN   NaN   1.0   NaN
# 342   NaN   NaN   NaN   NaN   NaN   NaN
# 343   NaN   NaN   NaN   NaN   NaN   NaN
# 344   NaN   NaN   NaN   NaN   NaN   NaN
# 345   NaN   NaN   NaN   NaN   NaN   NaN
# 346   NaN   NaN   NaN   NaN   NaN   NaN
# 347   NaN   NaN   NaN   NaN   NaN   NaN
# 348   NaN   NaN   NaN   NaN   NaN   NaN
# 349   NaN   NaN   NaN   NaN   NaN   NaN
# 350   NaN   NaN   NaN   NaN   1.0   NaN
# 351   NaN   NaN   NaN   NaN   NaN   NaN
# 352   NaN   NaN   NaN   NaN   NaN   NaN
# 353   NaN   NaN   NaN   NaN   1.0   NaN
# 354   NaN   NaN   NaN   NaN   NaN   NaN
# 355   NaN   NaN   NaN   NaN   NaN   NaN
# 356   NaN   NaN   NaN   NaN   NaN   NaN
# 357   NaN   NaN   NaN   NaN   1.0   NaN
# 358   NaN   NaN   NaN   NaN   NaN   NaN
# 359   NaN   NaN   NaN   NaN   NaN   NaN
# 360   NaN   NaN   NaN   NaN   NaN   NaN
# 361   1.0   NaN   NaN   NaN   1.0   NaN
# 362   NaN   NaN   NaN   NaN   NaN   NaN
# 363   NaN   NaN   NaN   NaN   NaN   NaN
# 364   NaN   NaN   NaN   NaN   NaN   NaN
#
# [365 rows x 22 columns]

# %%
# Dropped the columns that we do not need in final dataframe.
chi_weather=chi_weather.drop(columns = ['STATION','NAME','AWND', 'SNOW','SNWD','TMAX','TMIN','WDF2', 'WDF5','WSF2', 'WSF5', 'WT01', 'WT02', 'WT03','WT04','WT05','WT06','WT08','WT09'])

# %%
# Converted the dates into the datetime format.
chi_weather['DATE']=pd.to_datetime(chi_weather["DATE"])

# %%
chi_weather.head()
# Out:
#         DATE  PRCP  TAVG
# 0 2019-01-01  0.01    31
# 1 2019-01-02  0.01    28
# 2 2019-01-03  0.00    29
# 3 2019-01-04  0.00    37
# 4 2019-01-05  0.00    39

# %%
# Created a new daily date dataframe with the date range of 1/1/19 to 12/31/19.
weeks_2019_weather = pd.date_range('2019-1-1', '2019-12-31', freq = "D").to_series()

# %%
# Got the number of the week for each date on daily data frame.
weeks_2019_weather = weeks_2019_weather.dt.week

# %%
# Converted new Weeks series in  to dataframe, reset the index and dropped additional index column and renamed 'Week' to column.
Weeks_2019_df = weeks_2019_weather.to_frame().reset_index().drop(columns=['index']).rename(columns={'week':'Week'})

# %%
Weeks_2019_df
# Out:
#       0
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    3
# 14    3
# 15    3
# 16    3
# 17    3
# 18    3
# 19    3
# 20    4
# 21    4
# 22    4
# 23    4
# 24    4
# 25    4
# 26    4
# 27    5
# 28    5
# 29    5
# ..   ..
# 335  49
# 336  49
# 337  49
# 338  49
# 339  49
# 340  49
# 341  49
# 342  50
# 343  50
# 344  50
# 345  50
# 346  50
# 347  50
# 348  50
# 349  51
# 350  51
# 351  51
# 352  51
# 353  51
# 354  51
# 355  51
# 356  52
# 357  52
# 358  52
# 359  52
# 360  52
# 361  52
# 362  52
# 363   1
# 364   1
#
# [365 rows x 1 columns]

# %%
# Changed the column name to week.
new_names = ['week']
Weeks_2019_df.columns = new_names
Weeks_2019_df
# Out:
#      week
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# 5       1
# 6       2
# 7       2
# 8       2
# 9       2
# 10      2
# 11      2
# 12      2
# 13      3
# 14      3
# 15      3
# 16      3
# 17      3
# 18      3
# 19      3
# 20      4
# 21      4
# 22      4
# 23      4
# 24      4
# 25      4
# 26      4
# 27      5
# 28      5
# 29      5
# ..    ...
# 335    49
# 336    49
# 337    49
# 338    49
# 339    49
# 340    49
# 341    49
# 342    50
# 343    50
# 344    50
# 345    50
# 346    50
# 347    50
# 348    50
# 349    51
# 350    51
# 351    51
# 352    51
# 353    51
# 354    51
# 355    51
# 356    52
# 357    52
# 358    52
# 359    52
# 360    52
# 361    52
# 362    52
# 363    52
# 364    52
#
# [365 rows x 1 columns]

# %%
# Find out the weeks data types
Weeks_2019_df.dtypes
# Out:
# week    int64
# dtype: object

# %%
# Since 12/30/31 is technically Week #1 of Jan. 2020, we need to convert to Week 53 by doing it we will prevent adding values to Week 1 data
Weeks_2019_df.iloc[[363],0]=52

# %%
# Same with this date, since 12/31/31 is technically Week #1 of Jan. 2020, we needed to convert to Week 53. This will prevent adding values to Week 1 data.

Weeks_2019_df.iloc[[364],0]=52

# %%
# Final Weather dataframes by week:
Weeks_2019_df
# Out:
#      week
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# 5       1
# 6       2
# 7       2
# 8       2
# 9       2
# 10      2
# 11      2
# 12      2
# 13      3
# 14      3
# 15      3
# 16      3
# 17      3
# 18      3
# 19      3
# 20      4
# 21      4
# 22      4
# 23      4
# 24      4
# 25      4
# 26      4
# 27      5
# 28      5
# 29      5
# ..    ...
# 335    49
# 336    49
# 337    49
# 338    49
# 339    49
# 340    49
# 341    49
# 342    50
# 343    50
# 344    50
# 345    50
# 346    50
# 347    50
# 348    50
# 349    51
# 350    51
# 351    51
# 352    51
# 353    51
# 354    51
# 355    51
# 356    52
# 357    52
# 358    52
# 359    52
# 360    52
# 361    52
# 362    52
# 363    52
# 364    52
#
# [365 rows x 1 columns]

# %%
# Combined the week dataframe with the rest of the dataframe. Each date now has its respective week number.
joined_weather_n_weeks_df = pd.concat([Weeks_2019_df,chi_weather], axis="columns", join="inner")

# %%
# Final Avg. Weather dataframe by week:
joined_weather_n_weeks_df
# Out:
#      week       DATE  PRCP  TAVG
# 0       1 2019-01-01  0.01    31
# 1       1 2019-01-02  0.01    28
# 2       1 2019-01-03  0.00    29
# 3       1 2019-01-04  0.00    37
# 4       1 2019-01-05  0.00    39
# 5       1 2019-01-06  0.00    38
# 6       2 2019-01-07  0.44    44
# 7       2 2019-01-08  0.00    41
# 8       2 2019-01-09  0.00    23
# 9       2 2019-01-10  0.00    18
# 10      2 2019-01-11  0.00    23
# 11      2 2019-01-12  0.12    30
# 12      2 2019-01-13  0.01    30
# 13      3 2019-01-14  0.00    25
# 14      3 2019-01-15  0.00    26
# 15      3 2019-01-16  0.00    31
# 16      3 2019-01-17  0.00    30
# 17      3 2019-01-18  0.12    30
# 18      3 2019-01-19  0.18    26
# 19      3 2019-01-20  0.00    12
# 20      4 2019-01-21  0.00     9
# 21      4 2019-01-22  0.18    19
# 22      4 2019-01-23  0.22    29
# 23      4 2019-01-24  0.00    17
# 24      4 2019-01-25  0.03     1
# 25      4 2019-01-26  0.06     2
# 26      4 2019-01-27  0.00     4
# 27      5 2019-01-28  0.53    18
# 28      5 2019-01-29  0.00     6
# 29      5 2019-01-30  0.00   -15
# ..    ...        ...   ...   ...
# 335    49 2019-12-02  0.00    32
# 336    49 2019-12-03  0.00    32
# 337    49 2019-12-04  0.00    37
# 338    49 2019-12-05  0.00    36
# 339    49 2019-12-06  0.00    38
# 340    49 2019-12-07  0.00    31
# 341    49 2019-12-08  0.00    38
# 342    50 2019-12-09  0.05    46
# 343    50 2019-12-10  0.00    22
# 344    50 2019-12-11  0.00    18
# 345    50 2019-12-12  0.00    28
# 346    50 2019-12-13  0.00    40
# 347    50 2019-12-14  0.00    33
# 348    50 2019-12-15  0.00    24
# 349    51 2019-12-16  0.01    26
# 350    51 2019-12-17  0.00    25
# 351    51 2019-12-18  0.00    20
# 352    51 2019-12-19  0.00    23
# 353    51 2019-12-20  0.00    30
# 354    51 2019-12-21  0.00    38
# 355    51 2019-12-22  0.00    40
# 356    52 2019-12-23  0.00    42
# 357    52 2019-12-24  0.00    40
# 358    52 2019-12-25  0.00    47
# 359    52 2019-12-26  0.00    56
# 360    52 2019-12-27  0.00    37
# 361    52 2019-12-28  0.28    34
# 362    52 2019-12-29  0.93    52
# 363    52 2019-12-30  0.09    38
# 364    52 2019-12-31  0.08    26
#
# [365 rows x 4 columns]

# %%
# 
Divvy_Trips_2019_Q1_link = 'https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2019_Q1.zip'
Divvy_Trips_2019_Q2_link = 'https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2019_Q2.zip'
Divvy_Trips_2019_Q3_link = 'https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2019_Q3.zip'
Divvy_Trips_2019_Q4_link = 'https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2019_Q4.zip'

# %%
#
file_path = 'https://www.kaggle.com/chicago/chicago-beach-swim,-weather,-lab-data?select=beach-weather-stations-automated-sensors.csv'
df = pd.read_csv('https://www.kaggle.com/chicago/chicago-beach-swim,-weather,-lab-data?select=beach-weather-stations-automated-sensors.csv')
df.head()

# %%
# 
getfolder1 = requests.get(Divvy_Trips_2019_Q1_link)
getfolder2 = requests.get(Divvy_Trips_2019_Q2_link)
getfolder3 = requests.get(Divvy_Trips_2019_Q3_link)
getfolder4 = requests.get(Divvy_Trips_2019_Q4_link)

# %%
getfolder5 = requests.get(chi_weather_link)

# %%
#
unzipfolder1 = zipfile.ZipFile(io.BytesIO(getfolder1.content))
unzipfolder2 = zipfile.ZipFile(io.BytesIO(getfolder2.content))
unzipfolder3 = zipfile.ZipFile(io.BytesIO(getfolder3.content))
unzipfolder4 = zipfile.ZipFile(io.BytesIO(getfolder4.content))

# %%
unzipfolder5 = zipfile.ZipFile(io.BytesIO(getfolder5.content))

# %%
#
unzipfolder1.extractall('./Q1/Divvy_Trips_2019_Q1')
unzipfolder2.extractall('./Q2/Divvy_Trips_2019_Q2')
unzipfolder3.extractall('./Q3/Divvy_Trips_2019_Q3')
unzipfolder4.extractall('./Q4/Divvy_Trips_2019_Q4')

# %%
# 
os.rename("./Q1/Divvy_Trips_2019_Q1/Divvy_Trips_2019_Q1","./Q1/Divvy_Trips_2019_Q1/Divvy_Trips_2019_Q1.csv")
os.rename("./Q2/Divvy_Trips_2019_Q2/Divvy_Trips_2019_Q2","./Q2/Divvy_Trips_2019_Q2/Divvy_Trips_2019_Q2.csv")

# %%
# 
Q1_df = pd.read_csv('./Q1/Divvy_Trips_2019_Q1/Divvy_Trips_2019_Q1.csv')
Q2_df = pd.read_csv('./Q2/Divvy_Trips_2019_Q2/Divvy_Trips_2019_Q2.csv')
Q3_df = pd.read_csv('./Q3/Divvy_Trips_2019_Q3/Divvy_Trips_2019_Q3.csv')
Q4_df = pd.read_csv('./Q4/Divvy_Trips_2019_Q4/Divvy_Trips_2019_Q4.csv')

# %%
# 
Q2_df = Q2_df.rename(
    columns={'01 - Rental Details Rental ID' : 'trip_id'
             , '01 - Rental Details Local Start Time' : 'start_time'
             ,'01 - Rental Details Local End Time' : 'end_time'
             ,'01 - Rental Details Bike ID' : 'bikeid'
             ,'01 - Rental Details Duration In Seconds Uncapped' : 'tripduration'
             ,'03 - Rental Start Station ID' : 'from_station_id'
             ,'03 - Rental Start Station Name' : 'from_station_name'
             ,'02 - Rental End Station ID' : 'to_station_id'
             ,'02 - Rental End Station Name' : 'to_station_name'
             ,'User Type' : 'usertype'
             ,'Member Gender' : 'gender'
             ,'05 - Member Details Member Birthday Year' : 'birthyear'}
)

# %%
# 
joined_Divvy_data = Q1_df.append([Q2_df,Q3_df,Q4_df], ignore_index=True, sort=False)

# %%
# 
joined_Divvy_data.drop(columns=[
    'trip_id'
    , 'end_time', 'bikeid'
    , 'from_station_id'
    , 'from_station_name'
    , 'to_station_id'
    ,'to_station_name'], inplace=True)

# %%
# 
joined_Divvy_data_split = joined_Divvy_data['start_time'].str.split(" ", n = 1, expand = True)

# %%
# 
joined_Divvy_data_split = joined_Divvy_data_split.rename(columns={0:'Date'})

# %%
# 
joined_Divvy_data_split.drop(columns=[1], inplace=True)

# %%
# 
joined_Divvy_data_split['Date']=pd.to_datetime(joined_Divvy_data_split.Date)

# %%
# 
joined_Divvy_data_split['Date']=joined_Divvy_data_split['Date'].dt.strftime('%m/%d/%Y')

# %%
# 
joined_Divvy_data_all = pd.concat([joined_Divvy_data, joined_Divvy_data_split], axis="columns", join="inner")

# %%
# 
joined_Divvy_data_all.drop(columns=['start_time'], inplace=True)

# %%
# 
joined_Divvy_data_all = joined_Divvy_data_all.rename(columns={'usertype':'User_Type', 'tripduration':'Trip_Duration_min', 'gender':'Gender', 'birthyear':'Birth_Year'})

# %%
# Cleansing nulls from Joined Dataframe by replacing NAN values with empty strings.
Full_Divvy_data = joined_Divvy_data_all.fillna("")

# %%
# 
Full_Divvy_data = Full_Divvy_data[['Date', 'User_Type', 'Trip_Duration_min', 'Gender', 'Birth_Year']]
Full_Divvy_data.head()

# %%
# 
Total_2019_Users = joined_Divvy_data_all.groupby('Date').User_Type.count().to_frame().rename(columns={'User_Type':'Total_2019_Users'}).reset_index()
Total_2019_Users.head()

# %%
# 
Weeks_2019 = pd.date_range('2018-12-31', '2019-12-30', freq='D').to_series()

# %%
# 
Weeks_2019 = Weeks_2019.dt.isocalendar().week

# %%
# 
Weeks_2019_df = Weeks_2019.to_frame().reset_index().drop(columns=['index']).rename(columns={'week':'Week'})

# %%
# 
Weeks_2019_df.iloc[[364],['Week']]=52

# %%
# 
Weeks_2019_df.loc[len(Weeks_2019_df.index)]=52

# %%
# 
Weeks_2019_df = Weeks_2019_df.drop(labels=0, axis=0)

# %%
# 
Weeks_2019_df = Weeks_2019_df.reset_index().drop(columns=['index'])

# %%
# 
Weekly_df = pd.concat([Weeks_2019_df, Total_2019_Users], axis="columns", join="inner")
Weekly_df

# %%
# 
Weekly_Divvy_Users_df = Weekly_df.groupby('Week').Total_2019_Users.sum().reset_index()

# %%
# 
Weekly_Divvy_Users_df

# %%
# 
Weekly_Divvy_Users_df.to_csv(r'../Weekly_Divvy_Users.csv', index=False)

# %%
# 
Divvy_data = joined_Divvy_data_all
Divvy_data.dropna(inplace=True)

# %%
# 
Divvy_data['Birth_Year'] = Divvy_data['Birth_Year'].astype(int)

# %%
# 
Divvy_data['Trip_Duration_min']=Divvy_data['Trip_Duration_min'].str.replace('.,','')

# %%
# 
Divvy_data['Trip_Duration_min'] = Divvy_data['Trip_Duration_min'].astype(float).astype(int)

# %%
# 
Divvy_data['Trip_Duration_min'] = Divvy_data['Trip_Duration_min']/60

# %%
# 
Divvy_data['Trip_Duration_min'] = Divvy_data['Trip_Duration_min'].round(1).astype(float)

# %%
Divvy_data['Date'] = pd.to_datetime(Divvy_data.Date)

# %%
# 
Divvy_data = Divvy_data[['Date', 'User_Type', 'Trip_Duration_min', 'Gender', 'Birth_Year']]
Divvy_data.head()

# %%
# 
Divvy_data

# %%
# 
Divvy_data.dtypes

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#
